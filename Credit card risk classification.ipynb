# %% [markdown]
# # IMPORTING PACKAGES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # IGNORE WARNINGS

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # READING CSV FILES

# %%
df=pd.read_csv(r"C:\Users\welcome\Downloads\customer_data.csv")

# %%
df
# Out:
#       label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0         1  54982665      5  1245.5      3   77000.0      2     15      5
# 1         0  59004779      4  1277.0      1  113000.0      2      8     -1
# 2         0  58990862      7  1298.0      1  110000.0      2     11     -1
# 3         1  58995168      7  1335.5      1  151000.0      2     11      5
# 4         0  54987320      7     NaN      2   59000.0      2     11      5
# ...     ...       ...    ...     ...    ...       ...    ...    ...    ...
# 1120      0  58988196      5  1289.0      1  173000.0      2     15      5
# 1121      0  58987926      5     NaN      2   50000.0      2     15      5
# 1122      0  58995381      7  1220.0      3   76000.0      2     11      2
# 1123      0  58998054      4  1250.0      3  137000.0      2      8      5
# 1124      0  54989781      4  1415.0      3   93000.0      2      8      5
#
#       fea_8  fea_9  fea_10      fea_11
# ...

# %%
df1=pd.read_csv(r"C:\Users\welcome\Downloads\payment_data.csv")

# %%
df1
# Out:
#             id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0     58987402       0       0       0        0           1         10
# 1     58995151       0       0       0        0           1          5
# 2     58997200       0       0       0        0           2          5
# 3     54988608       0       0       0        0           3         10
# 4     54987763       0       0       0        0           2         10
# ...        ...     ...     ...     ...      ...         ...        ...
# 8245  58995478       0       0       0        0           9         15
# 8246  54992408       0       0       0        0           1          2
# 8247  54988209       0       0       0        0           5         13
# 8248  54992408       0       0       0        0           1          2
# 8249  54989207       0       0       0        0           1          5
#
#       prod_limit update_date  new_balance  highest_balance report_date
# ...

# %%
df.columns
# Out:
# Index(['label', 'id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
#        'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11'],
#       dtype='object')

# %% [markdown]
# # MERGING THE DATASET

# %%
df2=pd.merge(df,df1,on='id',how='inner')

# %%
df2
# Out:
#       label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0         1  54982665      5  1245.5      3   77000.0      2     15      5
# 1         1  54982665      5  1245.5      3   77000.0      2     15      5
# 2         1  54982665      5  1245.5      3   77000.0      2     15      5
# 3         1  54982665      5  1245.5      3   77000.0      2     15      5
# 4         0  59004779      4  1277.0      1  113000.0      2      8     -1
# ...     ...       ...    ...     ...    ...       ...    ...    ...    ...
# 8245      0  58998054      4  1250.0      3  137000.0      2      8      5
# 8246      0  58998054      4  1250.0      3  137000.0      2      8      5
# 8247      0  54989781      4  1415.0      3   93000.0      2      8      5
# 8248      0  54989781      4  1415.0      3   93000.0      2      8      5
# 8249      0  54989781      4  1415.0      3   93000.0      2      8      5
#
# ...

# %%
df2.nunique()
# Out:
# label                 2
# id                 1125
# fea_1                 6
# fea_2               158
# fea_3                 3
# fea_4               229
# fea_5                 2
# fea_6                10
# fea_7                10
# fea_8                52
# fea_9                 5
# fea_10              280
# fea_11              266
# OVD_t1               21
# OVD_t2               16
# OVD_t3               33
# OVD_sum             393
# pay_normal           37
# prod_code            21
# prod_limit          321
# update_date        3041
# new_balance        3939
# highest_balance    5140
# report_date        1862
# dtype: int64

# %%
df2.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8245    False
# 8246    False
# 8247    False
# 8248    False
# 8249    False
# Length: 8250, dtype: bool

# %%
df2.describe()
# Out:
#              label            id        fea_1        fea_2        fea_3  \
# count  8250.000000  8.250000e+03  8250.000000  7222.000000  8250.000000
# mean      0.168121  5.782173e+07     5.522667  1286.156813     2.319636
# std       0.373997  1.822724e+06     1.388358    52.002429     0.887414
# min       0.000000  5.498235e+07     1.000000  1116.500000     1.000000
# 25%       0.000000  5.499050e+07     4.000000  1248.500000     1.000000
# 50%       0.000000  5.898905e+07     5.000000  1283.000000     3.000000
# 75%       0.000000  5.899655e+07     7.000000  1317.500000     3.000000
# max       1.000000  5.900624e+07     7.000000  1481.000000     3.000000
#
#               fea_4        fea_5        fea_6        fea_7        fea_8  ...  \
# count  8.250000e+03  8250.000000  8250.000000  8250.000000  8250.000000  ...
# mean   1.386712e+05     1.940848    11.013939     4.881091   100.026303  ...
# std    1.081565e+05     0.235922     2.694611     3.031902    12.540081  ...
# ...

# %%
df2.columns
# Out:
# Index(['label', 'id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
#        'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
#        'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
#        'update_date', 'new_balance', 'highest_balance', 'report_date'],
#       dtype='object')

# %%
df2.shape
# Out:
# (8250, 24)

# %%
df2.isnull().sum()
# Out:
# label                 0
# id                    0
# fea_1                 0
# fea_2              1028
# fea_3                 0
# fea_4                 0
# fea_5                 0
# fea_6                 0
# fea_7                 0
# fea_8                 0
# fea_9                 0
# fea_10                0
# fea_11                0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# update_date          26
# new_balance           0
# highest_balance     409
# report_date        1114
# dtype: int64

# %%
not_req=['report_date','update_date']

# %%
df2.drop(labels=not_req,axis=1,inplace=True)

# %%
df2.columns
# Out:
# Index(['label', 'id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
#        'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
#        'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
#        'new_balance', 'highest_balance'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# label                int64
# id                   int64
# fea_1                int64
# fea_2              float64
# fea_3                int64
# fea_4              float64
# fea_5                int64
# fea_6                int64
# fea_7                int64
# fea_8                int64
# fea_9                int64
# fea_10               int64
# fea_11             float64
# OVD_t1               int64
# OVD_t2               int64
# OVD_t3               int64
# OVD_sum              int64
# pay_normal           int64
# prod_code            int64
# prod_limit         float64
# new_balance        float64
# highest_balance    float64
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8250 entries, 0 to 8249
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   label            8250 non-null   int64
#  1   id               8250 non-null   int64
#  2   fea_1            8250 non-null   int64
#  3   fea_2            7222 non-null   float64
#  4   fea_3            8250 non-null   int64
#  5   fea_4            8250 non-null   float64
#  6   fea_5            8250 non-null   int64
#  7   fea_6            8250 non-null   int64
#  8   fea_7            8250 non-null   int64
#  9   fea_8            8250 non-null   int64
#  10  fea_9            8250 non-null   int64
#  11  fea_10           8250 non-null   int64
#  12  fea_11           8250 non-null   float64
#  13  OVD_t1           8250 non-null   int64
#  14  OVD_t2           8250 non-null   int64
#  15  OVD_t3           8250 non-null   int64
#  16  OVD_sum          8250 non-null   int64
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
sns.barplot(data=df2,x='OVD_t1',y='OVD_t2')
plt.show()

# %%
df2["OVD_t1"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
sns.boxenplot(y=df2['pay_normal'],x=df2['label'],data=df2)
plt.title("correlation between the label and pay_normal",fontdict={'color':'purple'},size=16)
plt.show()

# %%
df2.hist(bins=50,figsize=(50,40),color='violet');

# %%
categories=['prod_code','prod_limit','highest_balance']
value=[25,40,30]
plt.bar(categories,value,color='purple')
plt.xlabel('prod_limit')
plt.ylabel('highest_balance')
plt.title('prod_code')
plt.show()

# %%
df2.sample(250).plot.scatter(x='highest_balance',y='prod_limit',color='red')
# Out:
# <Axes: xlabel='highest_balance', ylabel='prod_limit'>

# %%
sns.boxplot(data=df2,x='fea_1',y='fea_2')
plt.show()

# %%
df=pd.DataFrame(data=df2,columns=['OVD_t1','OVD_t2','OVD_t3'])
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # HEATMAP TO FIND THE CORRELATION

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df2.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# calculate correlation matrix
## using non-parametric test of correlation (kendall), since some features are binary
corrs = df2.select_dtypes(include=np.number).corr(method = 'kendall')

# plot clustered heatmap of correlations
sns.clustermap(corrs, cmap='coolwarm', center=0);

# %%
service = ['fea_1', 'fea_2', 'fea_3', 'fea_4',
       'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11']

fig, axes = plt.subplots(nrows = 3,ncols = 3,figsize = (15,12))
for i, item in enumerate(service):
    if i < 3:
        ax = df2[item].value_counts().plot(kind = 'bar',ax=axes[i,0],rot = 0,color = 'red')
        
    elif i >=3 and i < 6:
        ax = df2[item].value_counts().plot(kind = 'bar',ax=axes[i-3,1],rot = 0,color = 'green')
        
    elif i < 9:
        ax = df2[item].value_counts().plot(kind = 'bar',ax=axes[i-6,2],rot = 0,color = 'blue')
    ax.set_title(item)

# %%
columns_to_fill = ['label', 'id','fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
       'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
       'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit'
        , 'new_balance', 'highest_balance']
df2 = df2[columns_to_fill].fillna(0)

# %%
df2
# Out:
#       label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0         1  54982665      5  1245.5      3   77000.0      2     15      5
# 1         1  54982665      5  1245.5      3   77000.0      2     15      5
# 2         1  54982665      5  1245.5      3   77000.0      2     15      5
# 3         1  54982665      5  1245.5      3   77000.0      2     15      5
# 4         0  59004779      4  1277.0      1  113000.0      2      8     -1
# ...     ...       ...    ...     ...    ...       ...    ...    ...    ...
# 8245      0  58998054      4  1250.0      3  137000.0      2      8      5
# 8246      0  58998054      4  1250.0      3  137000.0      2      8      5
# 8247      0  54989781      4  1415.0      3   93000.0      2      8      5
# 8248      0  54989781      4  1415.0      3   93000.0      2      8      5
# 8249      0  54989781      4  1415.0      3   93000.0      2      8      5
#
# ...

# %%
df2.isnull().sum()
# Out:
# label              0
# id                 0
# fea_1              0
# fea_2              0
# fea_3              0
# fea_4              0
# fea_5              0
# fea_6              0
# fea_7              0
# fea_8              0
# fea_9              0
# fea_10             0
# fea_11             0
# OVD_t1             0
# OVD_t2             0
# OVD_t3             0
# OVD_sum            0
# pay_normal         0
# prod_code          0
# prod_limit         0
# new_balance        0
# highest_balance    0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['label', 'id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
#        'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
#        'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
#        'new_balance', 'highest_balance'],
#       dtype='object')

# %%
df2
# Out:
#       label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0         1  54982665      5  1245.5      3   77000.0      2     15      5
# 1         1  54982665      5  1245.5      3   77000.0      2     15      5
# 2         1  54982665      5  1245.5      3   77000.0      2     15      5
# 3         1  54982665      5  1245.5      3   77000.0      2     15      5
# 4         0  59004779      4  1277.0      1  113000.0      2      8     -1
# ...     ...       ...    ...     ...    ...       ...    ...    ...    ...
# 8245      0  58998054      4  1250.0      3  137000.0      2      8      5
# 8246      0  58998054      4  1250.0      3  137000.0      2      8      5
# 8247      0  54989781      4  1415.0      3   93000.0      2      8      5
# 8248      0  54989781      4  1415.0      3   93000.0      2      8      5
# 8249      0  54989781      4  1415.0      3   93000.0      2      8      5
#
# ...

# %%
df2.columns
# Out:
# Index(['label', 'id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
#        'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
#        'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
#        'new_balance', 'highest_balance'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8250 entries, 0 to 8249
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   label            8250 non-null   int64
#  1   id               8250 non-null   int64
#  2   fea_1            8250 non-null   int64
#  3   fea_2            8250 non-null   float64
#  4   fea_3            8250 non-null   int64
#  5   fea_4            8250 non-null   float64
#  6   fea_5            8250 non-null   int64
#  7   fea_6            8250 non-null   int64
#  8   fea_7            8250 non-null   int64
#  9   fea_8            8250 non-null   int64
#  10  fea_9            8250 non-null   int64
#  11  fea_10           8250 non-null   int64
#  12  fea_11           8250 non-null   float64
#  13  OVD_t1           8250 non-null   int64
#  14  OVD_t2           8250 non-null   int64
#  15  OVD_t3           8250 non-null   int64
#  16  OVD_sum          8250 non-null   int64
# ...

# %% [markdown]
# # MODEL_SELECTION AND ACCURACY PREDICTION

# %%
from sklearn.model_selection import train_test_split

x=df2[['id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
       'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
       'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
       'new_balance', 'highest_balance']]
y=df2['label']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
x_train
# Out:
#             id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  fea_8  \
# 3411  58995950      7  1218.5      1  101000.0      2     11      3    101
# 1870  59002803      4  1295.0      1   35000.0      2      8      5     90
# 1938  59000231      4  1425.5      3  146000.0      2      8      5    113
# 1077  59002016      4  1196.0      3   65000.0      2      8     -1    108
# 2305  54983331      5  1241.0      3   30000.0      2     15      5     80
# ...        ...    ...     ...    ...       ...    ...    ...    ...    ...
# 526   58995151      7     0.0      2  126000.0      2     11      9    115
# 1010  58987142      5  1310.0      1  500000.0      2     15      5    103
# 1389  58993402      7  1419.5      1   89000.0      2     11      5    110
# 2816  54987756      7  1257.5      3  144000.0      2     11      5    114
# 3167  54986029      7     0.0      2  127000.0      2     11     -1    110
#
# ...

# %%
x_test
# Out:
#             id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  fea_8  \
# 4875  58992627      7  1305.5      1   50000.0      2     12     -1    113
# 2264  54986068      7  1220.0      3  263000.0      2     11      9     90
# 5519  54992094      4  1296.5      1  127000.0      2      8      5    107
# 2940  54986897      7  1367.0      3  234000.0      2     11      5    113
# 4781  58996069      7  1233.5      3   62000.0      2     11      3     88
# ...        ...    ...     ...    ...       ...    ...    ...    ...    ...
# 6734  59005880      4  1241.0      1   86000.0      1      8      5    104
# 4056  54991404      4  1278.5      1  201000.0      2      8      5    102
# 2981  58996991      7  1197.5      3   63000.0      2     11     -1     93
# 6778  59004662      4  1242.5      3  158000.0      2      8      5    113
# 7765  58983266      5  1209.5      3   35000.0      2     15      5     78
#
# ...

# %%
y_train
# Out:
# 3411    1
# 1870    1
# 1938    0
# 1077    0
# 2305    0
#        ..
# 526     1
# 1010    0
# 1389    0
# 2816    0
# 3167    0
# Name: label, Length: 6600, dtype: int64

# %%
y_test
# Out:
# 4875    0
# 2264    0
# 5519    0
# 2940    0
# 4781    0
#        ..
# 6734    0
# 4056    0
# 2981    0
# 6778    0
# 7765    0
# Name: label, Length: 1650, dtype: int64

# %%
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
clf.fit(x,y)

y_pred=clf.predict(x_test)
score=accuracy_score(y_test,y_pred)
print("Accuracy : ",score)
# Out:
# Accuracy :  1.0

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(x_train, y_train)
y_pred = rf_classifier.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.97

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(x_train, y_train)
y_pred = knn_classifier.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.83

# %%
from sklearn.metrics import accuracy_score

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2, random_state=0)

clf.fit(x,y)

y_pred=clf.predict(x_test)
score=accuracy_score(y_test,y_pred)
print("Accuracy : ",score)
# Out:
# Accuracy :  0.8393939393939394

# %%
x_test.to_excel(r"C:\Users\welcome\Downloads\test.xlsx", index=False)

# %% [markdown]
# # BALANCING THE UNBALANCED DATA

# %%
pip install -U imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -lotly (c:\users\welcome\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\welcome\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\welcome\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\welcome\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\welcome\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\welcome\anaconda3\lib\site-packages)

# %%
import imblearn as i

# %%
x=df2.drop(['label'],axis=1)
y=df2['label']

# %%
f=x
g=y

# %%
y.value_counts()
# Out:
# 0    6863
# 1    1387
# Name: label, dtype: int64

# %%
y.value_counts().plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='label'>

# %% [markdown]
# # RANDOM UNDERSAMPLING

# %%
from imblearn.under_sampling import RandomUnderSampler
r=RandomUnderSampler(sampling_strategy=1)
x_res,y_res=r.fit_resample(x,y)

y_res.value_counts().plot.pie(autopct="%.2f").set_title("UNDERSAMPLING")
# Out:
# Text(0.5, 1.0, 'UNDERSAMPLING')

# %%
y_res.value_counts()
# Out:
# 0    1387
# 1    1387
# Name: label, dtype: int64

# %% [markdown]
# # RANDOM OVERSAMPLING

# %%
from imblearn.over_sampling import RandomOverSampler
r=RandomOverSampler(sampling_strategy=1)
x_r,y_r=r.fit_resample(f,g)

y_r.value_counts().plot.pie(autopct="%.2f").set_title("OVERERSAMPLING")
# Out:
# Text(0.5, 1.0, 'OVERERSAMPLING')

# %%
y_r.value_counts()
# Out:
# 1    6863
# 0    6863
# Name: label, dtype: int64

# %%
import pickle

# %%
import nbformat
import pickle
with open('AIML_FULLSTACK_FUTURA.ipynb', 'r', encoding='utf-8') as nb_file:
    notebook_content = nb_file.read()
notebook_dict = nbformat.reads(notebook_content, as_version=4)
with open(r"C:\Users\welcome\Downloads\output_notebook.pkl", 'wb') as pkl_file:
    pickle.dump(notebook_dict, pkl_file)

# %%
testData=pd.read_csv(r"C:\Users\welcome\Downloads\test.csv")

# %%
testData=testData.tail(500)

# %%
from sklearn.model_selection import train_test_split

x=testData[['id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
       'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
       'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
       'new_balance']]
y=testData['highest_balance']

X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
X_train
# Out:
#             id  fea_1   fea_2  fea_3   fea_4  fea_5  fea_6  fea_7  fea_8  \
# 1626  54987215      7  1296.5      3  136000      2     11      5    115
# 1380  58991921      7  1301.0      1   75000      2     11      7    112
# 1553  58995451      7  1248.5      3   60000      2     11      5     90
# 1230  54983792      5  1212.5      3  125000      2     15     10    113
# 1638  58992134      7  1235.0      1  114000      2     11     -1     85
# ...        ...    ...     ...    ...     ...    ...    ...    ...    ...
# 1646  54985110      7  1206.5      3   66000      2     11      5    104
# 1333  58987276      5     0.0      3   50000      2     15      9    110
# 1295  58999985      7  1281.5      3   98000      2     11      9    114
# 1468  54989304      4  1238.0      3  125000      2      8      9     85
# 1274  58993739      7  1307.0      1   80000      2     11      5     95
#
#       fea_9  fea_10      fea_11  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  \
# ...

# %%
X_test
# Out:
#             id  fea_1   fea_2  fea_3   fea_4  fea_5  fea_6  fea_7  fea_8  \
# 1637  58986183      5     0.0      2   72000      2     15      5    114
# 1404  58993422      7  1281.5      3   84000      2     11      5    113
# 1246  54987789      7  1289.0      3  130000      2     11      9     84
# 1523  54987233      7  1371.5      3  121000      2     11      9     85
# 1309  58982754      5  1322.0      3  195000      2     15      5     90
# ...        ...    ...     ...    ...     ...    ...    ...    ...    ...
# 1548  59001171      4  1200.5      3   69000      2      8      5    104
# 1362  54988011      7  1241.0      3   75000      2     11      5    110
# 1228  58987028      5  1206.5      3   49000      2     15      2    102
# 1170  54987320      7     0.0      2   59000      2     11      5    108
# 1239  58993081      7  1215.5      3   35000      2     11      9    113
#
#       fea_9  fea_10      fea_11  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  \
# ...

# %%
y_train
# Out:
# 1626      21950
# 1380      19700
# 1553      28100
# 1230      47500
# 1638      40019
#          ...
# 1646      10094
# 1333    1540194
# 1295      24623
# 1468          0
# 1274     671325
# Name: highest_balance, Length: 400, dtype: int64

# %%
y_test
# Out:
# 1637    400500
# 1404     11000
# 1246     59687
# 1523     47438
# 1309     65491
#          ...
# 1548     79204
# 1362    150500
# 1228     60865
# 1170    210500
# 1239    502500
# Name: highest_balance, Length: 100, dtype: int64

# %%
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
clf.fit(x,y)

y_pred=clf.predict(X_test)
score=accuracy_score(y_test,y_pred)
print("Accuracy : ",score)
# Out:
# Accuracy :  0.99

# %%
X_test.to_excel(r"C:\Users\welcome\Downloads\test_output.xlsx", index=False)
